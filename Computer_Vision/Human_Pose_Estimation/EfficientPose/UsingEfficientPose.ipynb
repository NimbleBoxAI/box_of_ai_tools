# %%
import numpy as np
from imp import load_source

import torch
from torch import load, quantization, backends

from eprt import KitModel
from helper import *

from scipy.ndimage.filters import gaussian_filter
import math

# %%
RES_PACK = {'rt': 224, 'i': 256, 'ii': 368, 'iii': 480, 'iv': 600, 'rt_lite': 224, 'i_lite': 256, 'ii_lite': 368}
MEANS = [0.406, 0.456, 0.485]
STDS = [0.225, 0.224, 0.229]

# %%
MainModel = load_source('MainModel', "eprt.py")
model = torch.load("weights/EfficientPoseRT")
model.eval()
qconfig = quantization.get_default_qconfig('qnnpack')
res = RES_PACK["rt"]
# Out:
# /usr/local/lib/python3.9/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'MainModel.KitModel' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.9/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /usr/local/lib/python3.9/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.batchnorm.BatchNorm2d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
image_transformations = get_transforms((res, res), MEANS, STDS)

# %%
model, res
# Out:
# (KitModel(
#    (stem_conv_res1_convolution): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#    (stem_bn_res1_FusedBatchNorm_1): BatchNorm2d(32, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block1a_dwconv_res1_depthwise): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False)
#    (block1a_bn_res1_FusedBatchNorm_1): BatchNorm2d(32, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block1a_se_reduce_res1_convolution): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#    (block1a_se_expand_res1_convolution): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#    (block1a_project_conv_res1_convolution): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (block1a_project_bn_res1_FusedBatchNorm_1): BatchNorm2d(16, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block2a_expand_conv_res1_convolution): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (block2a_expand_bn_res1_FusedBatchNorm_1): BatchNorm2d(96, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block2a_dwconv_res1_depthwise): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), groups=96, bias=False)
#    (block2a_bn_res1_FusedBatchNorm_1): BatchNorm2d(96, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block2a_se_reduce_res1_convolution): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#    (block2a_se_expand_res1_convolution): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#    (block2a_project_conv_res1_convolution): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (block2a_project_bn_res1_FusedBatchNorm_1): BatchNorm2d(24, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block2b_expand_conv_res1_convolution): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (block2b_expand_bn_res1_FusedBatchNorm_1): BatchNorm2d(144, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block2b_dwconv_res1_depthwise): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False)
#    (block2b_bn_res1_FusedBatchNorm_1): BatchNorm2d(144, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block2b_se_reduce_res1_convolution): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#    (block2b_se_expand_res1_convolution): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#    (block2b_project_conv_res1_convolution): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (block2b_project_bn_res1_FusedBatchNorm_1): BatchNorm2d(24, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block3a_expand_conv_res1_convolution): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (block3a_expand_bn_res1_FusedBatchNorm_1): BatchNorm2d(144, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block3a_dwconv_res1_depthwise): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), groups=144, bias=False)
#    (block3a_bn_res1_FusedBatchNorm_1): BatchNorm2d(144, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block3a_se_reduce_res1_convolution): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#    (block3a_se_expand_res1_convolution): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#    (block3a_project_conv_res1_convolution): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (block3a_project_bn_res1_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block3b_expand_conv_res1_convolution): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (block3b_expand_bn_res1_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block3b_dwconv_res1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (block3b_bn_res1_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (block3b_se_reduce_res1_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (block3b_se_expand_res1_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (block3b_project_conv_res1_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (block3b_project_bn_res1_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass1_block1_mbconv1_skeleton_conv1_convolution): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass1_block1_mbconv1_skeleton_conv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass1_block1_mbconv1_skeleton_dconv1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (pass1_block1_mbconv1_skeleton_dconv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass1_block1_mbconv1_skeleton_se_se_squeeze_conv_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (pass1_block1_mbconv1_skeleton_se_se_excite_conv_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (pass1_block1_mbconv1_skeleton_conv2_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass1_block1_mbconv1_skeleton_conv2_bn_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass1_block1_mbconv2_skeleton_conv1_convolution): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass1_block1_mbconv2_skeleton_conv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass1_block1_mbconv2_skeleton_dconv1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (pass1_block1_mbconv2_skeleton_dconv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass1_block1_mbconv2_skeleton_se_se_squeeze_conv_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (pass1_block1_mbconv2_skeleton_se_se_excite_conv_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (pass1_block1_mbconv2_skeleton_conv2_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass1_block1_mbconv2_skeleton_conv2_bn_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass1_block1_mbconv3_skeleton_conv1_convolution): Conv2d(80, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass1_block1_mbconv3_skeleton_conv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass1_block1_mbconv3_skeleton_dconv1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (pass1_block1_mbconv3_skeleton_dconv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass1_block1_mbconv3_skeleton_se_se_squeeze_conv_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (pass1_block1_mbconv3_skeleton_se_se_excite_conv_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (pass1_block1_mbconv3_skeleton_conv2_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass1_block1_mbconv3_skeleton_conv2_bn_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass2_block1_mbconv1_detection1_conv1_convolution): Conv2d(160, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass2_block1_mbconv1_detection1_conv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass2_block1_mbconv1_detection1_dconv1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (pass2_block1_mbconv1_detection1_dconv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass2_block1_mbconv1_detection1_se_se_squeeze_conv_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (pass2_block1_mbconv1_detection1_se_se_excite_conv_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (pass2_block1_mbconv1_detection1_conv2_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass2_block1_mbconv1_detection1_conv2_bn_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass2_block1_mbconv2_detection1_conv1_convolution): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass2_block1_mbconv2_detection1_conv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass2_block1_mbconv2_detection1_dconv1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (pass2_block1_mbconv2_detection1_dconv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass2_block1_mbconv2_detection1_se_se_squeeze_conv_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (pass2_block1_mbconv2_detection1_se_se_excite_conv_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (pass2_block1_mbconv2_detection1_conv2_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass2_block1_mbconv2_detection1_conv2_bn_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass2_block1_mbconv3_detection1_conv1_convolution): Conv2d(80, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass2_block1_mbconv3_detection1_conv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass2_block1_mbconv3_detection1_dconv1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (pass2_block1_mbconv3_detection1_dconv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass2_block1_mbconv3_detection1_se_se_squeeze_conv_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (pass2_block1_mbconv3_detection1_se_se_excite_conv_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (pass2_block1_mbconv3_detection1_conv2_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass2_block1_mbconv3_detection1_conv2_bn_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_block1_mbconv1_detection2_conv1_convolution): Conv2d(160, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass3_block1_mbconv1_detection2_conv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_block1_mbconv1_detection2_dconv1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (pass3_block1_mbconv1_detection2_dconv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_block1_mbconv1_detection2_se_se_squeeze_conv_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (pass3_block1_mbconv1_detection2_se_se_excite_conv_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (pass3_block1_mbconv1_detection2_conv2_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass3_block1_mbconv1_detection2_conv2_bn_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_block1_mbconv2_detection2_conv1_convolution): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass3_block1_mbconv2_detection2_conv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_block1_mbconv2_detection2_dconv1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (pass3_block1_mbconv2_detection2_dconv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_block1_mbconv2_detection2_se_se_squeeze_conv_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (pass3_block1_mbconv2_detection2_se_se_excite_conv_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (pass3_block1_mbconv2_detection2_conv2_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass3_block1_mbconv2_detection2_conv2_bn_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_block1_mbconv3_detection2_conv1_convolution): Conv2d(80, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass3_block1_mbconv3_detection2_conv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_block1_mbconv3_detection2_dconv1_depthwise): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False)
#    (pass3_block1_mbconv3_detection2_dconv1_bn_FusedBatchNorm_1): BatchNorm2d(240, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_block1_mbconv3_detection2_se_se_squeeze_conv_convolution): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#    (pass3_block1_mbconv3_detection2_se_se_excite_conv_convolution): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#    (pass3_block1_mbconv3_detection2_conv2_convolution): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#    (pass3_block1_mbconv3_detection2_conv2_bn_FusedBatchNorm_1): BatchNorm2d(40, eps=0.0010000000474974513, momentum=0.0, affine=True, track_running_stats=True)
#    (pass3_detection2_confs_convolution): Conv2d(120, 16, kernel_size=(1, 1), stride=(1, 1))
#  ),
#  224)

# %%
img = get_image_from_url("https://c.ndtvimg.com/2020-05/d35d9bog_virat-kohli-afp_625x300_18_May_20.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=806x605 at 0x10E43CD60>

# %%
out = image_transformations(img)
_, image_height, image_width = out.size()
out = model(out.view(1, *out.size())).detach().numpy()
out = np.rollaxis(out, 1, 4)
out.shape

# %%
frame_coords = extract_coordinates(out[0], image_height, image_width, real_time=False)

# %%
frame_coords
# Out:
# [('head_top', 0.4575892857142857, 0.09151785714285714),
#  ('upper_neck', 0.44419642857142855, 0.24776785714285715),
#  ('right_shoulder', 0.36830357142857145, 0.328125),
#  ('right_elbow', 0.41294642857142855, 0.5602678571428571),
#  ('right_wrist', 0.49776785714285715, 0.6808035714285714),
#  ('thorax', 0.43526785714285715, 0.30580357142857145),
#  ('left_shoulder', 0.49330357142857145, 0.3013392857142857),
#  ('left_elbow', 0.5200892857142857, 0.44419642857142855),
#  ('left_wrist', 0.5111607142857143, 0.5513392857142857),
#  ('pelvis', 0.44419642857142855, 0.546875),
#  ('right_hip', 0.3950892857142857, 0.5647321428571429),
#  ('right_knee', 0.3325892857142857, 0.8147321428571429),
#  ('right_ankle', 0.3013392857142857, 0.9174107142857143),
#  ('left_hip', 0.484375, 0.5424107142857143),
#  ('left_knee', 0.5602678571428571, 0.6227678571428571),
#  ('left_ankle', 0.4888392857142857, 0.9040178571428571)]

# %%
image = annotate_image(img, frame_coords)

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=806x605 at 0x10E43CD60>

# %%
torch.onnx.export(model, out.view(1, *out.size()), "sample.onnx")
# Out:
# eprt.py:147: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass1_block1_mbconv1_skeleton_conv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:148: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass1_block1_mbconv1_skeleton_dconv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:149: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass1_block1_mbconv1_skeleton_se_se_squeeze_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:150: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass1_block1_mbconv2_skeleton_conv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:151: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass1_block1_mbconv2_skeleton_dconv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:152: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass1_block1_mbconv2_skeleton_se_se_squeeze_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:153: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass1_block1_mbconv3_skeleton_conv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:154: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass1_block1_mbconv3_skeleton_dconv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:155: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass1_block1_mbconv3_skeleton_se_se_squeeze_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:156: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass2_block1_mbconv1_detection1_conv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:157: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass2_block1_mbconv1_detection1_dconv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:158: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass2_block1_mbconv1_detection1_se_se_squeeze_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:159: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass2_block1_mbconv2_detection1_conv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:160: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass2_block1_mbconv2_detection1_dconv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:161: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass2_block1_mbconv2_detection1_se_se_squeeze_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:162: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass2_block1_mbconv3_detection1_conv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:163: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass2_block1_mbconv3_detection1_dconv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:164: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass2_block1_mbconv3_detection1_se_se_squeeze_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:165: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass3_block1_mbconv1_detection2_conv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:166: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass3_block1_mbconv1_detection2_dconv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:167: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass3_block1_mbconv1_detection2_se_se_squeeze_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:168: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass3_block1_mbconv2_detection2_conv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:169: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass3_block1_mbconv2_detection2_dconv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:170: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass3_block1_mbconv2_detection2_se_se_squeeze_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:171: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass3_block1_mbconv3_detection2_conv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:172: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass3_block1_mbconv3_detection2_dconv1_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:173: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.pass3_block1_mbconv3_detection2_se_se_squeeze_eswish_mul_x = torch.autograd.Variable(torch.Tensor([1.25]), requires_grad=False)
# eprt.py:186: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   block1a_se_reshape_res1_Shape = torch.Tensor(list(block1a_se_squeeze_res1_Mean.size()))
# eprt.py:186: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   block1a_se_reshape_res1_Shape = torch.Tensor(list(block1a_se_squeeze_res1_Mean.size()))
# eprt.py:208: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   block2a_se_reshape_res1_Shape = torch.Tensor(list(block2a_se_squeeze_res1_Mean.size()))
# eprt.py:208: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   block2a_se_reshape_res1_Shape = torch.Tensor(list(block2a_se_squeeze_res1_Mean.size()))
# eprt.py:230: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   block2b_se_reshape_res1_Shape = torch.Tensor(list(block2b_se_squeeze_res1_Mean.size()))
# eprt.py:230: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   block2b_se_reshape_res1_Shape = torch.Tensor(list(block2b_se_squeeze_res1_Mean.size()))
# eprt.py:253: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   block3a_se_reshape_res1_Shape = torch.Tensor(list(block3a_se_squeeze_res1_Mean.size()))
# eprt.py:253: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   block3a_se_reshape_res1_Shape = torch.Tensor(list(block3a_se_squeeze_res1_Mean.size()))
# eprt.py:275: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   block3b_se_reshape_res1_Shape = torch.Tensor(list(block3b_se_squeeze_res1_Mean.size()))
# eprt.py:275: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   block3b_se_reshape_res1_Shape = torch.Tensor(list(block3b_se_squeeze_res1_Mean.size()))
# /Users/yashbonde/Desktop/wrk/box_of_ai_tools/Human_Pose_Estimation/EfficientPose/helper.py:75: TracerWarning: torch.Tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   return Tensor(bilinear_kernel)
